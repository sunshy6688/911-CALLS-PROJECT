# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
df = pd.read_pickle('all_banks')
df
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
df['BAC']['Close'].max()
# Out:
# 54.9

# %%
for ticks in tickers:
    print(ticks,df[ticks]['Close'].max())
# Out:
# BAC 54.9
# C 564.1
# GS 247.92
# JPM 70.08
# MS 89.3
# WFC 58.52

# %%
df.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
returns=pd.DataFrame()

# %%
for ticks in tickers:
    returns[ticks+' returns']=df[ticks]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC returns  C returns  GS returns  JPM returns  MS returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
#
#             WFC returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.000951
# 2006-01-06     0.005714
# 2006-01-09     0.000000

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BAC returns   2009-01-20
# C returns     2011-05-06
# GS returns    2009-01-20
# JPM returns   2009-01-20
# MS returns    2008-10-09
# WFC returns   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC returns   2009-04-09
# C returns     2011-05-09
# GS returns    2008-11-24
# JPM returns   2009-01-21
# MS returns    2008-10-13
# WFC returns   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC returns    0.036650
# C returns      0.179969
# GS returns     0.025346
# JPM returns    0.027656
# MS returns     0.037820
# WFC returns    0.030233
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC returns    0.016163
# C returns      0.015289
# GS returns     0.014046
# JPM returns    0.014017
# MS returns     0.016249
# WFC returns    0.012591
# dtype: float64

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS returns'],bins=100,color='green')
# Out:
# C:\Users\jyoti kumari\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='MS returns', ylabel='Density'>

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C returns'],bins=80,color='red')
# Out:
# C:\Users\jyoti kumari\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='C returns', ylabel='Density'>

# %%
for ticks in tickers:
    ticks,df[ticks]['Close'].plot(figsize=(12,4),label=ticks)
plt.legend()

# %%
df.xs(key='Close',axis=1,level='Stock Info').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="64711ff6-981e-446d-8ba4-d5c215a391a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['BAC']['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
df['BAC']['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %%
sns.heatmap(df.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(df.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
close_corr = df.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="84f5874e-47e2-48cc-a00b-c245c0c74d04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['BAC'][['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>                            <div id="e52060d3-fab0-44de-94b7-ad050eed32d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
